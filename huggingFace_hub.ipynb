# %%
import os
from dotenv import load_dotenv

load_dotenv()

READ_TOKEN = os.getenv("HF_TOKEN_READ")
WRITE_TOKEN = os.getenv("HF_TOKEN_WRITE")

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

result = generator("Artificial Intelligence is", max_new_tokens=30)

print(result[0]["generated_text"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 import torch  # <-- Add this line
#       2 from transformers import pipeline
#       3
# ----> 4 generator = pipeline("text-generation", model="gpt2")
#       5
#       6 result = generator("Artificial Intelligence is", max_new_tokens=30)
#       7
#
# File d:\ai_all\3_huggingFace\.venv\Lib\site-packages\transformers\pipelines\__init__.py:1024, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1019         raise ValueError(
#    1020             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#    1021             " arguments might conflict, use only one.)"
#    1022         )
#    1023 if dtype is not None:
# -> 1024     if isinstance(dtype, str) and hasattr(torch, dtype):
#    1025         dtype = getattr(torch, dtype)
#    1026     model_kwargs["dtype"] = dtype
#
# NameError: name 'torch' is not defined
